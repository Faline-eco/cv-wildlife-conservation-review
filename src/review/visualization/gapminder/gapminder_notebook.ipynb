# %%
from gapminder_explorer import load_and_prepare_many, widgets_explorer, load_many

# %%
papers = load_many([
    r"..\..\..\..\review_output\gapminder\2025117_manual.parquet",
    r"..\..\..\..\review_output\gapminder\2025117_auto.parquet",
])

# papers = load_and_prepare_many([
#     r"..\..\..\..\review_output\gapminder\manual.parquet",
#     r"..\..\..\..\review_output\gapminder\20250731_fixed.parquet",
# ])
# widgets_explorer(papers)

# %%
from gapminder_explorer_new import DataVisWidget
viz = DataVisWidget(papers)   # your DataFrame
viz.display()

# x = year
# y = Count[Species]
# color = imaging method
# size study_size
# Out:
# HBox(children=(VBox(children=(ToggleButtons(description='Chart', options=(('Scatter', 'scatter'), ('Stacked ba…
# Output()
